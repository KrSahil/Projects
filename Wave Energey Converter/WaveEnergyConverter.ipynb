# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Sydney_Data.csv')

# %%
df.columns = ['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','Y1','Y2','Y3','Y4','Y5','Y6','Y7','Y8','Y9','Y10','Y11','Y12','Y13','Y14','Y15','Y16','P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12','P13','P14','P15','P16','Total Power']

df.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  500.4677  278.6497   47.4062  417.3653  551.7083  401.1797    0.0000
# 1  511.7510  104.4383  566.0000  380.4079  345.8587    0.0000   90.5588
# 2   19.6990  216.4378  355.2960   67.8151  518.7256   72.1572  222.7933
# 3    0.0000    0.0000  243.3420    0.0000  566.0000    0.0000  198.4878
# 4  446.6611  421.0366  493.1895  566.0000  516.3773  566.0000  566.0000
#
#          X8        X9       X10  ...          P8           P9          P10  \
# 0  161.7773  368.1543   45.9850  ...  83029.8436   91483.7433   93748.1139
# 1    7.2899  566.0000  566.0000  ...  91309.1752  107598.5159  101897.2685
# 2  223.9242  566.0000  312.4474  ...  92083.6042  103182.5412   80688.8463
# 3    0.0000  566.0000  566.0000  ...  85602.1738   98370.5585   97148.3728
# 4  474.8170  566.0000    0.0000  ...  89796.6317  106234.3463   86528.7448
#
#            P11          P12          P13         P14          P15         P16  \
# ...

# %%
# Print the number of rows and columns
print('Number of Rows:', df.shape[0])
print('Number of Columns:', df.shape[1])
# Out:
# Number of Rows: 71999
# Number of Columns: 49

# %%
df = df.replace(0,np.nan)
print(df.isna().sum(axis = 0))
# Out:
# X1             4256
# X2             5376
# X3             7991
# X4             7109
# X5             3240
# X6             8164
# X7             7608
# X8             7075
# X9             6320
# X10            8300
# X11            5592
# X12            7328
# X13            5558
# X14            4143
# X15            6460
# X16            5677
# Y1             4225
# Y2             8380
# Y3             7769
# Y4             5925
# Y5             5289
# Y6             5025
# Y7             8065
# Y8             6877
# Y9             7627
# Y10            6416
# Y11            7097
# Y12            6669
# Y13            7098
# Y14            6767
# Y15            5218
# Y16            7786
# P1                0
# P2                0
# P3                0
# P4                0
# P5                0
# P6                0
# P7                0
# P8                0
# P9                0
# P10               0
# P11               0
# P12               0
# P13               0
# ...

# %%
# calculate the percentage of missing values for each column
missing_percentages = (df.isnull().sum() / len(df)) * 100

# %%
# create a list of column names with missing data greater than 20%
cols_to_drop = list(missing_percentages[missing_percentages > 20].index)

# %%
# drop the columns with missing data greater than 20%
df.drop(cols_to_drop, axis=1, inplace=True)

# print the new dataframe without the dropped columns
print(df.head())
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  500.4677  278.6497   47.4062  417.3653  551.7083  401.1797       NaN
# 1  511.7510  104.4383  566.0000  380.4079  345.8587       NaN   90.5588
# 2   19.6990  216.4378  355.2960   67.8151  518.7256   72.1572  222.7933
# 3       NaN       NaN  243.3420       NaN  566.0000       NaN  198.4878
# 4  446.6611  421.0366  493.1895  566.0000  516.3773  566.0000  566.0000
#
#          X8        X9       X10  ...          P8           P9          P10  \
# 0  161.7773  368.1543   45.9850  ...  83029.8436   91483.7433   93748.1139
# 1    7.2899  566.0000  566.0000  ...  91309.1752  107598.5159  101897.2685
# 2  223.9242  566.0000  312.4474  ...  92083.6042  103182.5412   80688.8463
# 3       NaN  566.0000  566.0000  ...  85602.1738   98370.5585   97148.3728
# 4  474.8170  566.0000       NaN  ...  89796.6317  106234.3463   86528.7448
#
#            P11          P12          P13         P14          P15         P16  \
# ...

# %%
df.isnull().sum()
# Out:
# X1             4256
# X2             5376
# X3             7991
# X4             7109
# X5             3240
# X6             8164
# X7             7608
# X8             7075
# X9             6320
# X10            8300
# X11            5592
# X12            7328
# X13            5558
# X14            4143
# X15            6460
# X16            5677
# Y1             4225
# Y2             8380
# Y3             7769
# Y4             5925
# Y5             5289
# Y6             5025
# Y7             8065
# Y8             6877
# Y9             7627
# Y10            6416
# Y11            7097
# Y12            6669
# Y13            7098
# Y14            6767
# Y15            5218
# Y16            7786
# P1                0
# P2                0
# P3                0
# P4                0
# P5                0
# P6                0
# P7                0
# P8                0
# P9                0
# P10               0
# P11               0
# P12               0
# P13               0
# ...

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='most_frequent')
df[['X1', 'X2','X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'Y1', 'Y2','Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9', 'Y10', 'Y11','Y12','Y13', 'Y14', 'Y15', 'Y16']] = imputer.fit_transform(df[['X1', 'X2','X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'Y1', 'Y2','Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9', 'Y10', 'Y11','Y12','Y13', 'Y14', 'Y15', 'Y16']])

# %%
print(df.isna().sum(axis = 0))
# Out:
# X1             0
# X2             0
# X3             0
# X4             0
# X5             0
# X6             0
# X7             0
# X8             0
# X9             0
# X10            0
# X11            0
# X12            0
# X13            0
# X14            0
# X15            0
# X16            0
# Y1             0
# Y2             0
# Y3             0
# Y4             0
# Y5             0
# Y6             0
# Y7             0
# Y8             0
# Y9             0
# Y10            0
# Y11            0
# Y12            0
# Y13            0
# Y14            0
# Y15            0
# Y16            0
# P1             0
# P2             0
# P3             0
# P4             0
# P5             0
# P6             0
# P7             0
# P8             0
# P9             0
# P10            0
# P11            0
# P12            0
# P13            0
# P14            0
# P15            0
# P16            0
# Total Power    0
# dtype: int64

# %%
df.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  71999.000000  71999.000000  71999.000000  71999.000000  71999.000000
# mean     357.590728    360.739283    311.471642    329.686944    389.590037
# std      191.170201    188.138335    208.614261    197.254973    150.089669
# min        0.003600      0.000100      0.005000      0.000100      0.000100
# 25%      188.894100    187.699800    103.349800    143.188400    275.226550
# 50%      408.528000    400.580300    315.712900    350.899100    408.981000
# 75%      543.273350    546.176100    537.798750    531.971200    533.320700
# max      566.000000    566.000000    566.000000    566.000000    566.000000
#
#                  X6            X7            X8            X9           X10  \
# count  71999.000000  71999.000000  71999.000000  71999.000000  71999.000000
# mean     334.895622    327.900286    306.826203    307.154342    329.082711
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(bins = 20, figsize = (30,20))
plt.show()

# %%
sns.distplot(df['Total Power'])
plt.show()
# Out:
# C:\Users\Sahil Kr Shah\AppData\Local\Temp\ipykernel_8536\3818184965.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total Power'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Create a scaler object
scaler = MinMaxScaler()

# Fit the scaler to the data
scaler.fit(df)

# Transform the data
normalized_data = scaler.transform(df)

# %%
col=df.columns

# %%
df
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      500.4677  278.6497   47.4062  417.3653  551.7083  401.1797  566.0000
# 1      511.7510  104.4383  566.0000  380.4079  345.8587  566.0000   90.5588
# 2       19.6990  216.4378  355.2960   67.8151  518.7256   72.1572  222.7933
# 3      566.0000  566.0000  243.3420  566.0000  566.0000  566.0000  198.4878
# 4      446.6611  421.0366  493.1895  566.0000  516.3773  566.0000  566.0000
# ...         ...       ...       ...       ...       ...       ...       ...
# 71994  545.2540  552.5709  558.6718  559.8935  562.3365  566.0000  562.3365
# 71995  559.8991  566.0000  561.1170  557.4535  553.7900  561.1070  556.2241
# 71996  564.7783  566.0000  564.7783  557.4613  547.7192  547.7192  542.8363
# 71997  566.0000  556.6139  551.3846  556.6139  559.7541  563.9395  559.7541
# 71998  566.0000  556.6139  551.3846  556.6139  559.7541  563.9395  559.7541
#
# ...

# %%
normalized_data = pd.DataFrame(data = normalized_data,columns=col)

# %%
normalized_data
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      0.884218  0.492314  0.083748  0.737394  0.974750  0.708797  1.000000
# 1      0.904153  0.184520  1.000000  0.672099  0.611058  1.000000  0.159984
# 2      0.034798  0.382399  0.627728  0.119815  0.916476  0.127484  0.393618
# 3      1.000000  1.000000  0.429928  1.000000  1.000000  1.000000  0.350675
# 4      0.789153  0.743881  0.871358  1.000000  0.912327  1.000000  1.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 71994  0.963346  0.976274  0.987053  0.989211  0.993527  1.000000  0.993527
# 71995  0.989221  1.000000  0.991373  0.984900  0.978428  0.991355  0.982728
# 71996  0.997842  1.000000  0.997842  0.984914  0.967702  0.967702  0.959074
# 71997  1.000000  0.983417  0.974178  0.983417  0.988965  0.996360  0.988965
# 71998  1.000000  0.983417  0.974178  0.983417  0.988965  0.996360  0.988965
#
# ...

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split
# Split the data into features (X) and target (y)
X = normalized_data.drop('Total Power', axis=1)
y = normalized_data['Total Power']

# Split the data into a training set and a validation set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Define the hyperparameter grids
linear_param_grid = {}
tree_param_grid = {'max_depth': [2, 4, 6, 8]}
forest_param_grid = {'n_estimators': [10, 50, 100], 'max_depth': [2, 4, 6, 8]}

# Create the models
linear = LinearRegression()
tree = DecisionTreeRegressor()
forest = RandomForestRegressor()

# Create the grid search objects
linear_search = GridSearchCV(linear, linear_param_grid)
tree_search = GridSearchCV(tree, tree_param_grid)
forest_search = GridSearchCV(forest, forest_param_grid)

# Fit the grid searches to the data
linear_search.fit(X_train, y_train)
tree_search.fit(X_train, y_train)
forest_search.fit(X_train, y_train)

# Print the best hyperparameters for each model
print('Best Hyperparameters for Linear Regression:', linear_search.best_params_)
print('Best iHyperparameters for Decision Tree Regression:', tree_search.best_params_)
print('Best Hyperparameters for Random Forest Regression:', forest_search.best_params_)
# Out:
# Best Hyperparameters for Linear Regression: {}
# Best Hyperparameters for Decision Tree Regression: {'max_depth': 8}
# Best Hyperparameters for Random Forest Regression: {'max_depth': 8, 'n_estimators': 50}

# %%
# Create new instances of the models with the optimal hyperparameters
linear = LinearRegression()
tree = DecisionTreeRegressor(max_depth=8)
forest = RandomForestRegressor(max_depth=8, n_estimators=50)

# Train the models on the training data
linear.fit(X_train, y_train)
tree.fit(X_train, y_train)
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=8, n_estimators=50)

# %%
# Make predictions on the test data using the trained models, mean squared error (MSE)
linear_y_pred = linear.predict(X_test)
tree_y_pred = tree.predict(X_test)
forest_y_pred = forest.predict(X_test)

# Evaluate the performance of the models using a suitable evaluation metric
from sklearn.metrics import mean_squared_error

linear_mse = mean_squared_error(y_test, linear_y_pred)
tree_mse = mean_squared_error(y_test, tree_y_pred)
forest_mse = mean_squared_error(y_test, forest_y_pred)

print('Mean Squared Error (MSE) for Linear Regression:', linear_mse)
print('Mean Squared Error (MSE) for Decision Tree Regression:', tree_mse)
print('Mean Squared Error (MSE) for Random Forest Regression:', forest_mse)
# Out:
# Mean Squared Error (MSE) for Linear Regression: 1.3307865635350097e-08
# Mean Squared Error (MSE) for Decision Tree Regression: 0.007308039547051595
# Mean Squared Error (MSE) for Random Forest Regression: 0.005506991941593411

# %%
# Calculate the Mean absolute error (MAE)
linear_mae = mean_absolute_error(y_test, linear_y_pred)
tree_mae = mean_absolute_error(y_test, tree_y_pred)
forest_mae = mean_absolute_error(y_test, forest_y_pred)


# Print the results
print('Linear Regression MAE:', linear_mae)
print('Decision Tree Regression MAE:', tree_mae)
print('Random Forest Regression MAE:', forest_mae)
# Out:
# Linear Regression MAE: 6.489078179670208e-06
# Decision Tree Regression MAE: 0.06743264117701218
# Random Forest Regression MAE: 0.0586570020317775

# %%
#Calculate R-squared

linear_r2 = r2_score(y_test, linear_y_pred)
tree_r2 = r2_score(y_test, tree_y_pred)
forest_r2 = r2_score(y_test, forest_y_pred)

print('Linear Regression R-squared:', linear_r2)
print('Decision Tree Regression R-squared:', tree_r2)
print('Random Forest Regression R-squared:', forest_r2)
# Out:
# Linear Regression R-squared: 0.9999992397169203
# Decision Tree Regression R-squared: 0.5824891108930301
# Random Forest Regression R-squared: 0.68538359883846

# %%
# Calculate Root Mean Squared Error(RMSE) for each model
linear_rmse = np.sqrt(mean_squared_error(y_test, linear_y_pred))
tree_rmse = np.sqrt(mean_squared_error(y_test, tree_y_pred))
forest_rmse = np.sqrt(mean_squared_error(y_test, forest_y_pred))

# Print the results
print('Linear Regression RMSE:', linear_rmse)
print('Decision Tree Regression RMSE:', tree_rmse)
print('Random Forest Regression RMSE:', forest_rmse)
# Out:
# Linear Regression RMSE: 0.0001153597227603729
# Decision Tree Regression RMSE: 0.08548707239724375
# Random Forest Regression RMSE: 0.07420910955936212
